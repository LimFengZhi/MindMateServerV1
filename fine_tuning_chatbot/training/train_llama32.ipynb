# %% [markdown]
# # QLoRA Fine-Tuning — Llama 3.2 1B (Mental-Health Counselor)
#
# Fine-tunes the **instruct** model on **MentalChat16K** with **reply-only loss**
# (no system prompt in training; loss on the counselor reply only). All
# hyperparameters live in `config.yaml`; the training routine is `trainer.py`.
#
# Saves the adapter + tokenizer + `run_info.json` to
# `../models/chat_models/mentalchat16k/llama32/`, then prints two held-out
# smoke-test generations.

# %%
import os
os.environ["PYTHONUTF8"] = "1"          # Windows charmap fix for TRL
os.environ["BNB_CUDA_VERSION"] = "130"  # torch is cu132; bitsandbytes tops out at cu130

import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))  # ft root (ft_utils, config)

import trainer

# %%
info = trainer.train("llama32")
# Out:
# === RUN llama32_mentalchat16k — MentalChat16K (ShenLab) ===
# ...
# Map:   0%|          | 0/2966 [00:00<?, ? examples/s]
# Train 10383 | Val 2966 | Test 1483
# Sample prompt:     "<|begin_of_text|><|start_header_id|>user<|end_header_id|>\n\nDoctor, I've been feeling an overwhelming sense of sadness and hopelessness that lingers da"
# Sample completion: "Based on the symptoms and challenges you've described, it's clear that you are dealing with a significant level of sadness and hopelessness, which is "
# WARNING: BNB_CUDA_VERSION=130 environment variable detected; loading libbitsandbytes_cuda130.dll.
# This can be used to load a bitsandbytes version built with a CUDA version that is different from the PyTorch CUDA version.
# If this was unintended set the BNB_CUDA_VERSION variable to an empty string: export BNB_CUDA_VERSION=
#
# W0801 21:05:30.286000 27084 Lib\site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
# ...

# %%
print(f"{info['run_name']}: {info['train_minutes']} min | "
      f"final train loss {info['final_train_loss']} | "
      f"best eval loss {info['best_eval_loss']}")
# Out:
# llama32_mentalchat16k: 165.2 min | final train loss 0.8772237960901638 | best eval loss 0.8733553886413574
